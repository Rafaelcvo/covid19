# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("covid19.csv")

# %%
df.isna().sum()
# Out:
# date                                0
# state                               0
# city                               16
# place_type                          0
# confirmed                           0
# deaths                              0
# is_last                             0
# estimated_population_2019           3
# city_ibge_code                      3
# confirmed_per_100k_inhabitants      3
# death_rate                        124
# dtype: int64

# %%
df = df.dropna(subset=['city'])

# %%
df.isna().sum()
# Out:
# date                                0
# state                               0
# city                                0
# place_type                          0
# confirmed                           0
# deaths                              0
# is_last                             0
# estimated_population_2019           3
# city_ibge_code                      3
# confirmed_per_100k_inhabitants      3
# death_rate                        108
# dtype: int64

# %%
df[df['city'] == "Belo Horizonte"]
# Out:
#           date state            city place_type  confirmed  deaths  is_last  \
# 0   2020-03-24    MG  Belo Horizonte       city         87       0     True
# 20  2020-03-23    MG  Belo Horizonte       city         60       0    False
# 41  2020-03-21    MG  Belo Horizonte       city         30       0    False
# 56  2020-03-20    MG  Belo Horizonte       city         20       0    False
# 69  2020-03-19    MG  Belo Horizonte       city         18       0    False
# 79  2020-03-18    MG  Belo Horizonte       city         10       0    False
# 89  2020-03-17    MG  Belo Horizonte       city          5       0    False
# 99  2020-03-16    MG  Belo Horizonte       city          1       0    False
#
#     estimated_population_2019  city_ibge_code  confirmed_per_100k_inhabitants  \
# 0                   2512070.0       3106200.0                         3.46328
# 20                  2512070.0       3106200.0                         2.38847
# ...

# %%
df.groupby('city').sum()
# Out:
#                     confirmed  deaths  is_last  estimated_population_2019  \
# city
# Belo Horizonte            231       0     True                 20096560.0
# Betim                       2       0     True                   878680.0
# Bom Despacho                2       0     True                   101210.0
# Campos Altos                2       0     True                    30922.0
# Contagem                    4       0     True                  1327710.0
# Coronel Fabriciano          8       0     True                   768985.0
# Divinópolis                15       0     True                  3573450.0
# Importados                 32       0     True                        0.0
# Ipatinga                   11       0     True                  2897510.0
# Juiz de Fora               34       0     True                  5119857.0
# Lagoa da Prata              2       0     True                   104330.0
# Mariana                     6       0     True                   242896.0
# ...
